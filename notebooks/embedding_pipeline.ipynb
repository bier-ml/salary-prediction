# %%
from core.embedding_models import EmbeddingModel, FastTextEmbeddingModel

# %%
fast_text_embedding = FastTextEmbeddingModel()

# %%
hf_embedding_model = EmbeddingModel()
# Out:
# .gitattributes:   0%|          | 0.00/744 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# 2_Dense/config.json:   0%|          | 0.00/114 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.36M [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/1.71k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/806 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/516M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/516M [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/461 [00:00<?, ?B/s]

# %%
fast_text_embedding.generate("Грузчик")
# Out:
# array([ 7.85222873e-02, -2.74757277e-02, -2.38787364e-02, -2.88884086e-03,
#         3.03315073e-02,  3.13737094e-02,  4.95969467e-02,  7.65075310e-05,
#        -4.56537902e-02,  1.47371024e-01, -3.26840170e-02,  2.41522375e-03,
#        -1.17779160e-02,  1.03981949e-01, -1.02461822e-01,  5.46226241e-02,
#        -6.92968816e-03, -5.39789051e-02, -3.49004678e-02,  1.86690539e-02,
#        -6.80883750e-02, -6.96855485e-02,  7.12529942e-02,  3.13525237e-02,
#         1.13536038e-01,  5.75968511e-02, -3.25138238e-03, -1.20729558e-01,
#         5.74089289e-02,  7.23615214e-02, -1.20455772e-03, -3.04935742e-02,
#         5.15083084e-03, -1.57532189e-02, -7.41013279e-03,  2.07652878e-02,
#         3.56081203e-02, -9.78515968e-02,  1.55240772e-02, -2.66970694e-02,
#         4.40014340e-02, -2.45497632e-03,  1.43599603e-03, -4.01896350e-02,
#        -7.92840719e-02, -3.00088227e-02,  1.65415648e-02,  5.29282503e-02,
# ...

# %%
s="""
Грузчик спрашивает грузчика
Грузчик. Какова твоя профессия?
"""
hf_embedding_model.generate("Грузчик")
# Out:
# array([-0.00859064, -0.0015416 , -0.03398206,  0.03184879, -0.07944697,
#         0.03510008, -0.01880946,  0.02476257, -0.04703587, -0.0489905 ,
#        -0.0758075 ,  0.04811362,  0.0361619 ,  0.00323653,  0.03399377,
#        -0.02533121,  0.00196838, -0.01969465, -0.00243339, -0.07418964,
#        -0.01804965,  0.02411151,  0.02014722,  0.04902511, -0.01237953,
#        -0.01291826,  0.0098616 , -0.01232527, -0.01355091,  0.00060655,
#        -0.00313636,  0.05010587,  0.04622833, -0.0381468 , -0.03701172,
#        -0.00624384, -0.04801828,  0.01532012,  0.03382432, -0.08306251,
#        -0.03717523,  0.05258506,  0.04381638, -0.07398745, -0.01725356,
#        -0.05433936,  0.00925901, -0.00883065, -0.01909242, -0.03145011,
#        -0.00990908,  0.0248251 ,  0.02278206, -0.07235431, -0.01655858,
#         0.03920335, -0.08637495, -0.05150352, -0.05435002, -0.03212895,
#        -0.00873522, -0.00124633, -0.00389272, -0.0053347 ,  0.01026419,
# ...
